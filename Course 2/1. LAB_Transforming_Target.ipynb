# %% [markdown]
# ## Learning objectives
#
# By the end of this lesson, you will be able to:
#
# * Apply transformations to make target variable more normally distributed for Regression
# * Apply inverse transformations to be able to use these in a Regression context

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
# %matplotlib inline

# Surpress warnings:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %% [markdown]
# In the following cells we will load the data and define some useful plotting functions.

# %%
np.random.seed(72018)


def to_2d(array):
    return array.reshape(array.shape[0], -1)
    
def plot_exponential_data():
    data = np.exp(np.random.normal(size=1000))
    plt.hist(data)
    plt.show()
    return data
    
def plot_square_normal_data():
    data = np.square(np.random.normal(loc=5, size=1000))
    plt.hist(data)
    plt.show()
    return data

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML240EN-SkillsNetwork/labs/data/boston_housing_clean.pickle"
response = requests.get(url)

# %% [markdown]
# ### Loading the Boston Housing Data

# %%
with open('boston_housing_clean.pickle', 'wb') as file:
    file.write(response.content)
    
with open('boston_housing_clean.pickle', 'rb') as to_read:
    boston = pd.read_pickle(to_read)
boston_data = boston['dataframe']
boston_description = boston['description']

# %%
boston_data.head(15)
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0   0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0  296.0
# 1   0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0  242.0
# 2   0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0  242.0
# 3   0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0  222.0
# 4   0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0  222.0
# 5   0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0  222.0
# 6   0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0  311.0
# 7   0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0  311.0
# 8   0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0  311.0
# 9   0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0  311.0
# 10  0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467  5.0  311.0
# 11  0.11747  12.5   7.87   0.0  0.524  6.009   82.9  6.2267  5.0  311.0
# 12  0.09378  12.5   7.87   0.0  0.524  5.889   39.0  5.4509  5.0  311.0
# 13  0.62976   0.0   8.14   0.0  0.538  5.949   61.8  4.7075  4.0  307.0
# 14  0.63796   0.0   8.14   0.0  0.538  6.096   84.5  4.4619  4.0  307.0
#
#     PTRATIO       B  LSTAT  MEDV
# 0      15.3  396.90   4.98  24.0
# 1      17.8  396.90   9.14  21.6
# 2      17.8  392.83   4.03  34.7
# 3      18.7  394.63   2.94  33.4
# 4      18.7  396.90   5.33  36.2
# 5      18.7  394.12   5.21  28.7
# 6      15.2  395.60  12.43  22.9
# 7      15.2  396.90  19.15  27.1
# 8      15.2  386.63  29.93  16.5
# 9      15.2  386.71  17.10  18.9
# 10     15.2  392.52  20.45  15.0
# 11     15.2  396.90  13.27  18.9
# 12     15.2  390.50  15.71  21.7
# 13     21.0  396.90   8.26  20.4
# 14     21.0  380.02  10.26  18.2

# %% [markdown]
# ### Determining Normality

# %% [markdown]
# Making our target variable normally distributed often will lead to better results
#
# If our target is not normally distributed, we can apply a transformation to it and then fit our regression to predict the transformed values.
#
# How can we tell if our target is normally distributed? There are two ways:
#
# * Using a Visual approach
# * Using a Statistical Test

# %% [markdown]
# #### Using a Visual approach

# %% [markdown]
# #### Plotting a histogram:

# %%
boston_data.MEDV.hist();

# %% [markdown]
# The histogram does not look normal due to its right tail.

# %% [markdown]
# #### Using a Statistical Test

# %% [markdown]
# Without getting into Bayesian vs. frequentist debates, for the purposes of this lesson, the following will suffice:
#
# * This is a statistical test that tests whether a distribution is normally distributed or not. It isn't perfect, but suffice it to say:
#     * This test outputs a **p-value**. The _higher_ this p-value is the _closer_ the distribution is to normal.
#     * Frequentist statisticians would say that you accept that the distribution is normal (more specifically: fail to reject the null hypothesis that it is normal) if p > 0.05.

# %%
from scipy.stats.mstats import normaltest # D'Agostino K^2 Test

# %%
normaltest(boston_data.MEDV.values)
# Out:
# NormaltestResult(statistic=np.float64(90.9746873700967), pvalue=np.float64(1.7583188871696098e-20))

# %% [markdown]
# The p-value which is 1.7583188871696098e-20 in reality means that we have 20 zeros before the 1:
#
# $p-value = 0.000000000000000000017583188871696098$

# %% [markdown]
# p-value is _extremely_ low. Our **y** variable which we have been dealing with this whole time was not normally distributed!

# %% [markdown]
# ### Apply transformations to make target variable more normally distributed for Regression

# %% [markdown]
# Linear Regression assumes a normally distributed residuals which can be aided by transforming **y** variable which is the target variable. Let's try some common transformations to try and get **y** to be normally distributed:
#
# * Log Transformation
# * Square root Transformation
# * Box cox Transformation

# %% [markdown]
# ### Log Transformation

# %% [markdown]
# The log transformation can transform data that is significantly skewed right to be more normally distributed:

# %% [markdown]
# **Apply transformation to Boston Housing data:**

# %%
log_medv = np.log(boston_data.MEDV)

# %%
log_medv.hist();

# %%
normaltest(log_medv)
# Out:
# NormaltestResult(statistic=np.float64(17.21801696640697), pvalue=np.float64(0.00018245472768345307))

# %% [markdown]
# Conclusion: The output is closer to normal distribution, but still not completely normal.

# %% [markdown]
# ### Square root Transformation
#
# The square root transformation is another transformation that can transform non-normally distributed data into normally distributed data:

# %% [markdown]
# #### Exercise

# %% [markdown]
# Apply the square root transformation to the Boston Housing data target and test whether the result is normally distributed.

# %%
sqrt_medv = np.sqrt(boston_data['MEDV'])
plt.hist(sqrt_medv)
# Out:
# (array([  9.,  18.,  40.,  67., 131., 121.,  48.,  36.,  10.,  26.]),
#  array([2.23606798, 2.71956796, 3.20306794, 3.68656793, 4.17006791,
#         4.65356789, 5.13706788, 5.62056786, 6.10406784, 6.58756783,
#         7.07106781]),
#  <BarContainer object of 10 artists>)

# %%
normaltest(sqrt_medv)
# Out:
# NormaltestResult(statistic=np.float64(20.487090826863067), pvalue=np.float64(3.558645701429252e-05))

# %%
sqrt_medv.skew()
# Out:
# np.float64(0.43893531933950786)

# %% [markdown]
# ### Box cox Transformation

# %% [markdown]
# The box cox transformation is a parametrized transformation that tries to get distributions "as close to a normal distribution as possible".
#
# It is defined as:
#
# $$ \text{boxcox}(y_i) = \frac{y_i^{\lambda} - 1}{\lambda} $$
#
# You can think of as a generalization of the square root function: the square root function uses the exponent of 0.5, but box cox lets its exponent vary so it can find the best one.

# %%
from scipy.stats import boxcox

# %%
bc_result = boxcox(boston_data['MEDV'])

boxcox_medv = bc_result[0]
lam = bc_result[1]

# %%
lam
# Out:
# np.float64(0.21662091178859486)

# %%
boston_data['MEDV'].hist();

# %%
plt.hist(boxcox_medv);

# %%
normaltest(boxcox_medv)
# Out:
# NormaltestResult(statistic=np.float64(4.513528743199032), pvalue=np.float64(0.10468867097426256))

# %% [markdown]
# We find that the box cox results in a graph which is significantly more normally distributed (according to p value) than the other two distributions.This can be even above 0.05.
#
# Now that we have a normally distributed y-variable, let's test Regression using this transformed target variables.

# %% [markdown]
# ### Testing regression:

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import (StandardScaler, PolynomialFeatures)

# %%
lr = LinearRegression()

# %% [markdown]
# **Define and load the predictor (X) and Target(y) variables**

# %%
y_col = 'MEDV'

X = boston_data.drop(y_col, axis = 1)
y = boston_data[y_col]
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %% [markdown]
# **Create Polynomial Features**

# %%
pf = PolynomialFeatures(degree = 2, include_bias = False)
X_pf = pf.fit_transform(X)
X_pf
# Out:
# array([[6.32000000e-03, 1.80000000e+01, 2.31000000e+00, ...,
#         1.57529610e+05, 1.97656200e+03, 2.48004000e+01],
#        [2.73100000e-02, 0.00000000e+00, 7.07000000e+00, ...,
#         1.57529610e+05, 3.62766600e+03, 8.35396000e+01],
#        [2.72900000e-02, 0.00000000e+00, 7.07000000e+00, ...,
#         1.54315409e+05, 1.58310490e+03, 1.62409000e+01],
#        ...,
#        [6.07600000e-02, 0.00000000e+00, 1.19300000e+01, ...,
#         1.57529610e+05, 2.23851600e+03, 3.18096000e+01],
#        [1.09590000e-01, 0.00000000e+00, 1.19300000e+01, ...,
#         1.54802902e+05, 2.54955600e+03, 4.19904000e+01],
#        [4.74100000e-02, 0.00000000e+00, 1.19300000e+01, ...,
#         1.57529610e+05, 3.12757200e+03, 6.20944000e+01]])

# %%
X.shape
# Out:
# (506, 13)

# %%
X_pf.shape
# Out:
# (506, 104)

# %% [markdown]
# **Split the data into Training and Test Sets**
#
# The split ratio here is 0.7 and 0.3 which means we will assign **70%** data for training and **30%** data for testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pf, y, test_size = 0.3, random_state=72018 )

# %%
X_train.shape
# Out:
# (354, 104)

# %% [markdown]
# **Normalize the training data using `StandardScaler` on `X_train`. Use fit_transform() function**

# %%
s = StandardScaler()
X_train_s = s.fit_transform(X_train)
X_train_s.shape
# Out:
# (354, 104)

# %% [markdown]
# **Discuss: what transformation do we need to apply next?**
#
# Apply the appropriate transformation.

# %%
bc_result2 = boxcox(y_train)

y_train_bc = bc_result2[0]
lam2 = bc_result2[1]
# It's the same that: y_train_bc, lam2 = bc_result2
y_train_bc
# Out:
# array([4.86256872, 6.06291788, 4.51310422, 4.81957911, 4.95725441,
#        5.77277513, 5.41197103, 5.7564064 , 3.72665154, 4.94686905,
#        5.7564064 , 4.80874124, 3.92225304, 4.58384079, 4.78695489,
#        6.64804038, 3.7730073 , 2.91446766, 3.99405238, 5.37557172,
#        2.91446766, 5.14858228, 3.3783037 , 5.61413707, 4.46503232,
#        6.62861297, 3.53307618, 3.78829071, 4.66439022, 4.74293125,
#        4.76501905, 4.58384079, 6.66093847, 4.90499291, 4.72068897,
#        5.15835234, 3.30653008, 3.15681305, 4.60706701, 6.00211597,
#        7.02952231, 4.68703021, 3.78829071, 5.05933498, 4.19940571,
#        4.93645047, 6.30368162, 7.02952231, 5.65657873, 4.54867384,
#        4.59547548, 4.60706701, 4.84114572, 5.37557172, 3.93675684,
#        4.22573747, 4.60706701, 4.47712076, 4.54867384, 5.61413707,
#        4.93645047, 2.39638824, 4.88385039, 3.67951377, 5.08935181,
#        4.78695489, 6.22514014, 4.92599843, 6.02503493, 4.10535841,
#        4.4284789 , 4.59547548, 5.51012874, 3.51631102, 5.05933498,
#        4.54867384, 5.90897306, 4.58384079, 4.05023624, 4.58384079,
#        7.02952231, 5.45693443, 4.87322708, 4.47712076, 7.02952231,
#        4.65300894, 5.01888291, 3.1179925 , 7.02952231, 4.57216255,
#        5.0693709 , 5.10921288, 2.02481768, 4.54867384, 4.63012207,
#        4.86256872, 2.87170164, 4.96760681, 4.65300894, 4.9882137 ,
#        5.89321439, 3.78829071, 4.69828962, 5.08935181, 4.68703021,
#        5.17780712, 3.78829071, 2.97726951, 4.84114572, 5.76460015,
#        4.58384079, 4.7539943 , 4.40386528, 3.69531519, 5.15835234,
#        3.80349167, 4.77600581, 6.02503493, 4.39148366, 5.32023547,
#        5.59701583, 2.82818202, 5.51891562, 2.02481768, 5.69851575,
#        4.47712076, 4.41619687, 4.86256872, 5.17780712, 4.02228006,
#        5.50131956, 4.57216255, 4.31611542, 3.25138808, 5.46585715,
#        5.63966343, 5.55384283, 6.04781153, 4.61861574, 4.84114572,
#        3.67951377, 4.44071184, 4.59547548, 4.05023624, 6.13753538,
#        4.05023624, 5.89321439, 4.7095091 , 6.12273183, 2.69276615,
#        4.83038051, 4.87322708, 6.19616668, 5.0693709 , 5.03917107,
#        4.44071184, 6.48309307, 4.89443891, 4.99846868, 5.51891562,
#        4.93645047, 3.3783037 , 4.9882137 , 4.64158634, 5.07937644,
#        5.19714941, 4.97792649, 5.12895581, 7.02952231, 3.48246659,
#        7.02952231, 5.81337196, 4.17283872, 6.12273183, 4.92599843,
#        4.3033695 , 3.74218881, 4.64158634, 5.3109247 , 5.03917107,
#        4.37905151, 4.59547548, 4.00820055, 5.1387835 , 4.7539943 ,
#        4.22573747, 4.68703021, 5.54514381, 4.65300894, 6.20343113,
#        6.06291788, 5.33878087, 2.62209386, 5.04926844, 7.02952231,
#        5.90897306, 4.96760681, 5.49248795, 5.63966343, 5.41197103,
#        4.56044036, 3.53307618, 4.63012207, 5.10921288, 5.1387835 ,
#        4.66439022, 4.52500618, 4.76501905, 5.0693709 , 4.15946543,
#        6.7500554 , 4.97792649, 4.10535841, 4.31611542, 4.50115628,
#        4.74293125, 6.71210985, 5.55384283, 4.95725441, 6.14491506,
#        4.87322708, 5.02904263, 2.9565104 , 3.89302343, 4.66439022,
#        4.63012207, 3.95118782, 4.56044036, 4.67573052, 4.45289616,
#        3.74218881, 4.83038051, 5.3295208 , 4.80874124, 4.53686258,
#        3.81861124, 4.80874124, 4.95725441, 3.67951377, 5.69016804,
#        4.25183889, 4.7095091 , 4.7095091 , 4.26480471, 3.66362191,
#        5.04926844, 4.94686905, 3.90767554, 4.72068897, 4.10535841,
#        3.4481928 , 5.6734133 , 7.02952231, 3.84861027, 4.17283872,
#        6.38062123, 4.46503232, 4.85187503, 5.11909901, 7.02952231,
#        6.83104049, 4.60706701, 4.87322708, 4.45289616, 4.69828962,
#        2.62209386, 5.44798858, 6.5829017 , 4.50115628, 4.53686258,
#        4.99846868, 4.47712076, 4.87322708, 5.10921288, 4.06411444,
#        4.72068897, 7.02952231, 5.14858228, 3.95118782, 4.67573052,
#        2.62209386, 4.9882137 , 4.02228006, 4.00820055, 4.29056945,
#        3.64763837, 4.57216255, 4.34144697, 3.84861027, 4.97792649,
#        4.10535841, 4.46503232, 3.58276154, 6.54991794, 5.3295208 ,
#        5.82948279, 4.68703021, 3.84861027, 4.69828962, 4.77600581,
#        4.48916194, 4.84114572, 4.74293125, 5.00869167, 5.17780712,
#        3.36054166, 2.89317691, 4.87322708, 4.57216255, 3.28827778,
#        4.17283872, 5.3664111 , 4.97792649, 5.17780712, 4.72068897,
#        3.96554684, 4.25183889, 4.9882137 , 5.0693709 , 5.11909901,
#        5.29222619, 5.41197103, 3.93675684, 4.23881667, 5.05933498,
#        4.50115628, 4.91551266, 4.91551266, 6.04023502, 5.71515243,
#        4.84114572, 4.26480471, 5.12895581, 4.34144697, 6.10786888,
#        5.17780712, 3.81861124, 5.73171148, 5.86944684, 2.20407039,
#        3.28827778, 4.89443891, 5.83751118, 5.17780712, 5.85351441,
#        5.04926844, 4.78695489, 4.36656835, 4.39148366, 4.81957911,
#        5.47475688, 5.20677886, 4.02228006, 4.34144697])

# %% [markdown]
# As before, we'll now:
#
# 1. Fit regression
# 1. Transform testing data
# 1. Predict on testing data

# %%
y_train_bc.shape
# Out:
# (354,)

# %%
lr.fit(X_train_s, y_train_bc) # we're stablishing our parameters, it will fit our LR to the X and y
X_test_s = s.transform(X_test)
y_pred_bc = lr.predict(X_test_s)

# %%
y_test
# Out:
# 502    20.6
# 127    16.2
# 390    15.1
# 303    33.1
# 277    33.1
#        ...
# 433    14.3
# 505    11.9
# 53     23.4
# 82     24.8
# 377    13.3
# Name: MEDV, Length: 152, dtype: float64

# %%
y_pred_bc
# Out:
# array([4.4392342 , 4.16090928, 4.15308658, 5.72559281, 5.70300643,
#        6.59889512, 4.18332001, 4.77591019, 4.68614576, 4.85728949,
#        6.83944548, 3.76006133, 5.06792522, 4.366021  , 6.91067234,
#        4.94872356, 4.64047978, 5.83610114, 5.25013614, 5.44752214,
#        3.97745097, 4.88502896, 4.20357879, 3.61242521, 5.23497779,
#        5.30389206, 5.86527586, 4.79984562, 4.79631521, 6.80365128,
#        3.36716519, 4.39738313, 4.298454  , 6.96423331, 4.49871237,
#        5.52039179, 4.8001967 , 5.61272414, 3.05186393, 5.34227359,
#        3.34081629, 3.97104152, 5.13918248, 4.3799833 , 5.06134125,
#        6.28670359, 4.90206081, 5.25595643, 5.69828211, 4.21011239,
#        5.23206192, 5.48921777, 4.37075215, 3.94811697, 4.15121064,
#        2.74849191, 4.06553469, 3.13202418, 4.55300092, 4.80245929,
#        5.74892338, 3.2618593 , 3.53812201, 6.17778723, 4.23622528,
#        5.82374079, 3.41359682, 3.83978181, 4.96307822, 5.74303973,
#        5.20656217, 5.22395333, 5.25945062, 5.43876017, 3.83969336,
#        3.49918965, 5.39730928, 4.44473736, 4.37572439, 4.43688033,
#        4.22547252, 4.86897936, 5.84864429, 4.04130037, 3.53265705,
#        3.18748061, 4.6212383 , 6.02948779, 4.69902379, 6.75306433,
#        4.36369878, 7.09943587, 3.63055522, 6.85938906, 5.95013455,
#        4.85771685, 3.32284693, 3.07438149, 4.97033808, 5.04698301,
#        2.26308811, 3.36965548, 3.93673479, 5.25273867, 5.72696698,
#        5.42008624, 4.63577009, 4.0827288 , 3.91983818, 5.48236222,
#        6.38390359, 4.60023209, 5.78586653, 4.98065723, 4.79781356,
#        5.75179695, 6.64970459, 3.79106158, 5.26210331, 5.06006439,
#        5.27013182, 4.06623284, 4.90212385, 3.99490236, 5.22160967,
#        5.40844924, 4.58314618, 4.22235125, 4.77844872, 4.81397495,
#        5.20935079, 4.23445058, 4.98240212, 4.94957625, 4.87367353,
#        4.81078135, 3.13127106, 3.71024116, 5.64602691, 4.81458533,
#        3.62625398, 4.97601485, 4.81222562, 4.45918276, 5.63725995,
#        6.18903597, 2.48233697, 4.26886445, 4.33422538, 4.90868284,
#        5.18281401, 3.47607573])

# %% [markdown]
# ### Discussion
#
# * Are we done?
# * What did we predict?
# * How would you interpret these predictions?

# %% [markdown]
# #### Apply inverse transformations to be able to use these in a Regression context

# %% [markdown]
# Every transformation has an inverse transformation. The inverse transformation of $f(x) = \sqrt{x}$ is $f^{-1}(x) = x^2$, for example. Box cox has an inverse transformation as well: notice that we have to pass in the lambda value that we found from before:

# %%
from scipy.special import inv_boxcox

# %%
inv_boxcox(boxcox_medv, lam)[:10]
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9])

# %%
boston_data['MEDV'].values[:10]
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9])

# %% [markdown]
# Exactly the same, as we would hope!

# %% [markdown]
# ### Exercise:
#
# 1. Apply the appropriate inverse transformation to `y_pred_bc`.
# 2. Calculate the $R^2$ using the result of this inverse transformation and `y_test`.
#
# **Hint:** Use the **inv_boxcox()** function to get the transformed predicted values

# %%
#Enter your code here
y_pred_tran = inv_boxcox(y_pred_bc, lam2)
r2_score(y_test, y_pred_tran)
# Out:
# 0.8884878248134334

# %% [markdown]
# ## Practice Exercise:
#
# ### Determine the R^2 of a LinearRegression without the box cox transformation.

# %%
# Enter your code here
lr = LinearRegression()
lr.fit(X_train_s, y_train)
lr_pred = lr.predict(X_test_s)

r2_score(y_test, lr_pred)
# Out:
# 0.8689110469231008

# %% [markdown]
# <details><summary>Click here for a sample python solution</summary>
#
# ```python
# lr = LinearRegression()
# lr.fit(X_train_s,y_train)
# lr_pred = lr.predict(X_test_s)
# r2_score(y_test,lr_pred)
#
# ```
